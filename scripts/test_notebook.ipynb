# %%
import Pkg
Pkg.activate("/Users/andreas/src/julia/BiochemicalVisualization.jl")
using BiochemicalAlgorithms, BiochemicalVisualization, Bonito
Page()

# %%
sys = load_pdb(ball_data_path("../test/data/AlaAla.pdb"))
infer_topology!(sys);

# %%
stick(sys)

# %%
stick(sys)
