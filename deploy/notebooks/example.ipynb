# %% [markdown]
# # BiochemicalVisualization — interactive viewer
#
# Run the cells below. Rotate/zoom with touch, and use the sidebar + top menu to change models, opacity, and coloring — every control round-trips to the live Julia kernel.
#
# `Page()` ships the JS bundle once for the whole notebook.

# %%
using BiochemicalAlgorithms, BiochemicalVisualization, Bonito
Page()

# %%
# A small structure that ships with BiochemicalAlgorithms.
sys = load_pdb(ball_data_path("../test/data/AlaAla.pdb"))
infer_topology!(sys);
# Out:
# [ Info: reconstruct_fragments!(): added 0 atoms.
# [ Info: build_bonds!(): built 22 bonds

# %%
ball_and_stick(sys)
# Out:
# Failed to bundle /proxy/34763/assets/8638a9a86a985dbe2664b3a04c06356d3fea52e9-biochemicalvisualization.bundled.js?cc4b71d0bb73e00cae6188d8d2a5e05f7723c08c: /proxy/34763/assets/8638a9a86a985dbe2664b3a04c06356d3fea52e9-biochemicalvisualization.bundled.bundled.js. bundle_dir: nothing
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] Asset(path_or_url::String; name::String, es6module::Bool, check_isfile::Bool, bundle_dir::Nothing, mediatype::Symbol)
#     @ Bonito /opt/julia-depot/packages/Bonito/OJTyF/src/asset-serving/asset.jl:184
#   [3] ES6Module
#     @ /opt/julia-depot/packages/Bonito/OJTyF/src/asset-serving/asset.jl:241 [inlined]
#   [4] _visualize()
#     @ BiochemicalVisualization /opt/bcv/src/core/visualize.jl:71
#   [5] _build_scene_app(scene::Scene)
#     @ BiochemicalVisualization /opt/bcv/src/core/visualize.jl:407
#   [6] show(io::IOContext{IOBuffer}, mime::MIME{Symbol("text/html")}, scene::Scene)
# ...

# %%
# Try a surface too:
# ses(sys)
